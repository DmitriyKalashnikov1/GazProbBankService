# %%
import numpy as np
import pandas as pd
import joblib
from sklearn.feature_extraction.text import CountVectorizer

# %%
PATH_TO_DF = "../data/dataset.csv"

# %%
df = pd.read_csv(PATH_TO_DF)
df.head(30)
# Out:
#     id              time  estimation  \
# 0    0  24.09.2025 17:36           5
# 1    1  22.09.2025 11:53           5
# 2    2  19.09.2025 14:39           5
# 3    3  21.09.2025 21:29           5
# 4    5  24.09.2025 13:46           5
# 5    6  24.09.2025 10:44           5
# 6    8  24.09.2025 14:12           5
# 7    9  21.09.2025 07:46           5
# 8   10  21.09.2025 07:17           5
# 9   11  24.09.2025 10:00           5
# 10  12  22.09.2025 11:33           5
# 11  13  21.09.2025 13:25           5
# 12  14  22.09.2025 16:37           5
# 13  15  21.09.2025 18:54           5
# 14  16  24.09.2025 14:44           5
# 15  17  24.09.2025 05:16           5
# 16  18  25.09.2025 10:56           5
# 17  19  23.09.2025 14:36           5
# 18  21  24.09.2025 16:38           5
# 19  22  24.09.2025 13:44           5
# 20  23  25.09.2025 11:32           5
# 21  24  24.09.2025 12:29           5
# 22  25  17.09.2025 05:58           5
# 23  26  18.09.2025 17:30           1
# 24  27  19.09.2025 11:03           1
# 25  28  19.09.2025 12:50           5
# 26  29  18.09.2025 10:20           5
# 27  30  18.09.2025 17:37           1
# 28  31  18.09.2025 16:01           5
# 29  32  17.09.2025 16:12           5
#
#                                                  text  \
# 0                   Решила заказать карту этого банка
# 1   Карту получила, доставка очень быстрая. Утром ...
# 2   Наконец-то я являюсь клиентом Газпромбанка. До...
# 3   На сайте газпромбанка заказала дебетовую карту...
# 4   Выражаю ОГРОМНУЮ благодарность работнику конта...
# 5   Я в восторге от того как быстро доставили карт...
# 6   Сегодня получил карту Хочу выразить благодарно...
# 7   Я решил открыть накопительный счёт "Ежедневный...
# 8   Очень быстро отработали вопрос о переводе дене...
# 9   Карту получил, доставка супер. Утром позвонила...
# 10  Здравствуйте.\nНа работе сказали оформить карт...
# 11  Заполнила на сайте заяку на выпуск дебетовой к...
# 12  Хочу поблагодарить представителя Ксению, понял...
# 13  Увидел на просторах интернета акцию «супермарк...
# 14  Добрый день, получил карту, доставила Ксения, ...
# 15  Сегодня, 25.08.2025 года, я получила дебетовую...
# 16  была встреча с представителем Т-ым Сергеем, Ка...
# 17  Хочу выразить большую благодарность, за достав...
# 18  получил карту, Ксения все рассказала про карту...
# 19  Карту получил, на все вопросы ответы тоже полу...
# 20  Добрый день , карту получил. Очень порадовала ...
# 21  Добрый день, получил сегодня 24.09.2025 в 13:0...
# 22  Очередь к сотрудникам банка была небольшая. Пр...
# 23  Обратился в чат 28.02.2025 утром в 10:46 с про...
# 24  Открыл накопительный счёт, пополнил его. Затем...
# 25  Заказал дебетовую карту Газпромбанка с доставк...
# 26  Хочу выразить благодарность представителю Газп...
# 27  Добрый день! 26 июля 2025 года подключил опцию...
# 28  Добрый день. Сегодня ждала свою карту дебетову...
# 29  Хочу оставить отзыв на представителя Александр...
#
#                                            textLemmas
# 0                          решить заказать карта банк
# 1   карта получить доставка очень быстрый утро поз...
# 2   наконецто являться клиент газпромбанк дорого с...
# 3   сайт газпромбанк заказать дебетовый карта запо...
# 4   выражать огромный благодарность работник конта...
# 5   восторг быстро доставить карта дом сделать зая...
# 6   сегодня получить карта хотеть выразить благода...
# 7   решить открыть накопительный счет ежедневный п...
# 8   очень быстро отработать вопрос перевод денежны...
# 9   карта получить доставка супер утро позвонить д...
# 10  здравствуйте работа сказать оформить карта сам...
# 11  заполнить сайт заяк выпуск дебетовый карта бан...
# 12  хотеть поблагодарить представитель ксения поня...
# 13  увидеть просторах интернет акция супермаркет м...
# 14  добрый день получить карта доставить ксения ут...
# 15  сегодня год получить дебетовый карта газпромба...
# 16  встреча представитель тым сергей качественный ...
# 17  хотеть выразить больший благодарность доставка...
# 18  получить карта ксения рассказать карта объясни...
# 19  карта получить вопрос ответ получить ксения су...
# 20  добрый день карта получить очень порадовать во...
# 21  добрый день получить сегодня 1300 карта ваш ба...
# 22  очередь сотрудник банк небольшой ожидание спас...
# 23  обратиться чат утро 1046 просьба пояснить дейс...
# 24  открыть накопительный счет пополнить затем нес...
# 25  заказать дебетовый карта газпромбанк доставка ...
# 26  хотеть выразить благодарность представитель га...
# 27  добрый день год подключить опция газпромбонус ...
# 28  добрый день сегодня ждать карта дебетовый газп...
# 29  хотеть оставить отзыв представитель александр ...

# %%
lemTexts = df["textLemmas"].dropna().to_list()

# %%
vectorizer = CountVectorizer(ngram_range=(1,2))

# обучаем count векторизатор
x = vectorizer.fit_transform(lemTexts)

print(f"Len of one vector: {x.shape[1]}")

# Смотрим на индексы комбинаций слов
features = vectorizer.get_feature_names_out()

words = {"key word": features}
index = [f for f in range(len(features))]

keyWordsDf = pd.DataFrame(data=words)

keyWordsDf.head(20)
# Out:
# Len of one vector: 314287
#          key word
# 0              00
# 1           00 22
# 2           00 56
# 3        00 вечер
# 4   00 дозвонится
# 5         00 копа
# 6      00 копейка
# 7         00 мочь
# 8          00 руб
# 9        00 самый
# 10     00 спасибо
# 11         00 час
# 12            000
# 13        000 000
# 14         000 13
# 15       000 2051
# 16         000 35
# 17         000 40
# 18         000 90
# 19       000 балл

# %%
keyWordsDf.to_csv("../data/keyWords.csv")

# %%
# Save
joblib.dump(vectorizer, "../data/CountVectLemmText.joblib")
# Out:
# ['../data/CountVectLemmText.joblib']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans
from time import time

clustersCount = 35
maxIter = 500
nInit = 10

# %%
maxDF = 0.5
minDF = 10

# %%
idfVectorizer = TfidfVectorizer(max_df=maxDF, min_df=minDF)
t0 = time()
X_tfidf = idfVectorizer.fit_transform(lemTexts)

print(f"vectorization done in {time() - t0:.3f} s")
print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")
# Out:
# vectorization done in 0.503 s
# n_samples: 9567, n_features: 3589

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

lsa = make_pipeline(TruncatedSVD(n_components=400), Normalizer(copy=False))
t0 = time()
X_lsa = lsa.fit_transform(X_tfidf)
explained_variance = lsa[0].explained_variance_ratio_.sum()

print(f"LSA done in {time() - t0:.3f} s")
print(f"Explained variance of the SVD step: {explained_variance * 100:.1f}%")
# Out:
# LSA done in 3.319 s
# Explained variance of the SVD step: 54.4%

# %%
print(f"n_samples: {X_lsa.shape[0]}, n_features: {X_lsa.shape[1]}")
# Out:
# n_samples: 9567, n_features: 400

# %%
kmeans = KMeans(
   n_clusters=clustersCount,
    max_iter=maxIter,
    n_init=nInit,
)

# %%
kmeans.fit(X_lsa)
# Out:
# KMeans(max_iter=500, n_clusters=35, n_init=10)

# %%
original_space_centroids = lsa[0].inverse_transform(kmeans.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]
terms = idfVectorizer.get_feature_names_out()

numC = [i for i in range(clustersCount)]

tops = []

for i in range(clustersCount):
    print(f"Cluster {i}: ", end="")
    clusterTop = []
    for ind in order_centroids[i, :10]:
        print(f"{terms[ind]} ", end="")
        clusterTop += [terms[ind]] 
    tops += [clusterTop] 
    print()
# Out:
# Cluster 0: премиум пакет подключить привилегия условие клиент менеджер 2990 обслуживание спорт
# Cluster 1: сертификат 1000 акция озон покупка ссылка оформить условие газпромбанк прислать
# Cluster 2: кэшбэк акция 35 условие покупка важный самый выполнить начислить месяц
# Cluster 3: подписка газпром привилегия отключить списать деньга подключить 2990 премиум бонус
# Cluster 4: заявка дебетовый оформить сайт оформление кредитный получение газпромбанк день подать
# Cluster 5: офис очередь сотрудник талон час клиент обслуживание человек работать время
# Cluster 6: услуга отключить подключить списать 2990 платный мой списание деньга согласие
# Cluster 7: рассказать очень представитель спасибо помочь быстро сотрудник объяснить подробно вопрос
# Cluster 8: средство денежный счет мой газпромбанк день списать деньга обращение возврат
# Cluster 9: деньга перевести счет перевод свой операция мой это газпромбанк день
# Cluster 10: премиальный менеджер клиент обслуживание являться персональный премиум пакет это программа
# Cluster 11: кешбэк акция 180 100 кредитный условие 35 важный день начислить
# Cluster 12: перевод комиссия сбп счет сбой май деньга операция свой газпромбанк
# Cluster 13: номер телефон приходить смс приложение код мочь офис зайти данные
# Cluster 14: добрый день сутки весь время уважаемый читатель сегодня хотеть вечер
# Cluster 15: оператор чат вопрос ответ бот отвечать занять поддержка приложение писать
# Cluster 16: встреча представитель назначить рассказать время договориться ксения доставка спасибо удобный
# Cluster 17: unionpay 5000 рубль юниона выпуск комиссия пить граница пэй месяц
# Cluster 18: счет накопительный процент открыть ставка открытие месяц день деньга газпромбанк
# Cluster 19: счет закрытие заявление закрыть деньга день написать офис 30 отделение
# Cluster 20: акция условие выполнить кэшбек бонус 35 участие начислить обращение важный
# Cluster 21: банкомат деньга газпромбанк внести наличные наличный средство снятие операция счет
# Cluster 22: условие месяц pay union 5000 руб рубль выпуск выполнить 000
# Cluster 23: обращение день мой документ ответ сказать это офис сотрудник который
# Cluster 24: кешбек акция условие 35 покупка начислить выполнить чат месяц начисление
# Cluster 25: доставка заказать курьер представитель дебетовый время день позвонить приехать доставить
# Cluster 26: газпромбанк клиент отзыв это приложение гпб хотеть поддержка ужасный отвратительный
# Cluster 27: год обслуживание кредитный бесплатный пользоваться закрыть являться комиссия 2024 задолженность
# Cluster 28: минута ожидание 30 оператор линия дозвониться время чат горячий час
# Cluster 29: вклад открыть процент деньга открытие счет офис ставка газпромбанк срок
# Cluster 30: кредитный период задолженность льготный процент платеж который дебетовый день сумма
# Cluster 31: балл акция начислить покупка условие 1000 5000 месяц бонусный 35
# Cluster 32: привилегия подключить отключить списать месяц услуга деньга 299 сервис руб
# Cluster 33: отделение адрес сотрудник обратиться получить газпромбанк час ул это очередь
# Cluster 34: друг ссылка условие выполнить акция вознаграждение привести пригласить получить оформить

# %%
mlDf = {"Cluster": numC, "TopWords": tops}
mlClusterResDF = pd.DataFrame(data=mlDf)

# %%
mlClusterResDF.head(20)
# Out:
#     Cluster                                           TopWords
# 0         0  [премиум, пакет, подключить, привилегия, услов...
# 1         1  [сертификат, 1000, акция, озон, покупка, ссылк...
# 2         2  [кэшбэк, акция, 35, условие, покупка, важный, ...
# 3         3  [подписка, газпром, привилегия, отключить, спи...
# 4         4  [заявка, дебетовый, оформить, сайт, оформление...
# 5         5  [офис, очередь, сотрудник, талон, час, клиент,...
# 6         6  [услуга, отключить, подключить, списать, 2990,...
# 7         7  [рассказать, очень, представитель, спасибо, по...
# 8         8  [средство, денежный, счет, мой, газпромбанк, д...
# 9         9  [деньга, перевести, счет, перевод, свой, опера...
# 10       10  [премиальный, менеджер, клиент, обслуживание, ...
# 11       11  [кешбэк, акция, 180, 100, кредитный, условие, ...
# 12       12  [перевод, комиссия, сбп, счет, сбой, май, день...
# 13       13  [номер, телефон, приходить, смс, приложение, к...
# 14       14  [добрый, день, сутки, весь, время, уважаемый, ...
# 15       15  [оператор, чат, вопрос, ответ, бот, отвечать, ...
# 16       16  [встреча, представитель, назначить, рассказать...
# 17       17  [unionpay, 5000, рубль, юниона, выпуск, комисс...
# 18       18  [счет, накопительный, процент, открыть, ставка...
# 19       19  [счет, закрытие, заявление, закрыть, деньга, д...

# %%
mlClusterResDF.to_csv("../data/mlClusterRes.csv")

# %%
mlClusterizator = make_pipeline(idfVectorizer, lsa, kmeans)

# %%
print(lemTexts[32])
# Out:
# 2330 проведение денежный перевод мой карта газпромбанк сбп свой счет другой банк заблокировать мой счет вход мобильный приложение причина проведение операция указание мошенник проводить операция находиться дома квартира чужой человек звонок посетить офис банк проспект вернадский д 37 2 сотрудник отказаться разблокировать счет мой объяснение удовлетворить подтверждение телефон сын пытаться забрать телефон проверка личный звонок вообще незаконно основание пенсионерка какой иметь право вести сомневаться мой финансовый грамотность удерживать мой деньга стаж работа банк 23 год такой обращение клиент еще сталкиваться написать заявление банк прислать сообщение рассматривать быть 3 неделя вопрос это правомерно банк лишать процент пользоваться мой деньга деньга идти лечение покупка лекарство больной муж лишить собственный деньга выдумать причина рекомендовать пользоваться никто услуга газпромбанк попасть подобный ситуация

# %%
cluster = mlClusterizator.predict([lemTexts[32]])

# %%
cluster
# Out:
# array([9], dtype=int32)

# %%
# Save
joblib.dump(mlClusterizator, "../data/mlClusterizatorLemmText.joblib")
# Out:
# ['../data/mlClusterizatorLemmText.joblib']
